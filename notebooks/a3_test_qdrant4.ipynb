# %%
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance, PointStruct
from sentence_transformers import SentenceTransformer
from rank_bm25 import BM25Okapi
import numpy as np
from langchain_text_splitters import RecursiveCharacterTextSplitter
import json
from langchain_qdrant import FastEmbedSparse, RetrievalMode
from langchain_qdrant import QdrantVectorStore
from langchain_core.documents import Document
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
QDRANT_URL = "http://127.0.0.1:6333"
COLLECTION_NAME = "hybrid_docs"
DATA_PATH = "../data/processed/proc_docx.jsonl"
EMBED_MODEL_NAME = 'intfloat/multilingual-e5-large'
EMBED_DIM = 1024

# %%
docs = []
with open(DATA_PATH, "r", encoding="utf-8") as f:
    for line in f:
        data = json.loads(line)
        text = data.get("text", "")
        meta = {
            "doc_id": data.get("doc_id", ""),
            "file_path": data.get("file_path", "")
        }
        if text.strip():
            docs.append({"text": text, "metadata": meta})

# %%
len(docs)
# Out:
# 31

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts, metadatas = [], []
for doc in docs:
    chunks = splitter.split_text(doc["text"])
    texts.extend(chunks)
    metadatas.extend([doc["metadata"]] * len(chunks))

# %%
len(texts), len(metadatas)
# Out:
# (53, 53)

# %%
texts = ['passage: ' + t for t in texts]

# %%
documents = [
    Document(page_content=texts[i], metadata=metadatas[i])
    for i in range(len(texts))
]

# %%
# emb = HuggingFaceEmbeddings(model_name=EMBED_MODEL_NAME)
# embedder = SentenceTransformer(EMBED_MODEL_NAME)
embedder = HuggingFaceEmbeddings(model_name=EMBED_MODEL_NAME)

# %%
sparse_embedder = FastEmbedSparse(model_name="Qdrant/bm25")
# Out:
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# dutch.txt:   0%|          | 0.00/453 [00:00<?, ?B/s]
# danish.txt:   0%|          | 0.00/424 [00:00<?, ?B/s]
# french.txt:   0%|          | 0.00/813 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# finnish.txt: 0.00B [00:00, ?B/s]
# arabic.txt: 0.00B [00:00, ?B/s]
# english.txt:   0%|          | 0.00/936 [00:00<?, ?B/s]
# greek.txt: 0.00B [00:00, ?B/s]
# german.txt: 0.00B [00:00, ?B/s]
# hungarian.txt: 0.00B [00:00, ?B/s]
# portuguese.txt: 0.00B [00:00, ?B/s]
# swedish.txt:   0%|          | 0.00/559 [00:00<?, ?B/s]
# russian.txt: 0.00B [00:00, ?B/s]
# italian.txt: 0.00B [00:00, ?B/s]
# romanian.txt: 0.00B [00:00, ?B/s]
# spanish.txt: 0.00B [00:00, ?B/s]
# norwegian.txt:   0%|          | 0.00/851 [00:00<?, ?B/s]
# turkish.txt:   0%|          | 0.00/260 [00:00<?, ?B/s]

# %%
qdrant = QdrantVectorStore.from_documents(
    documents,
    url=QDRANT_URL,
    embedding=embedder,
    sparse_embedding=sparse_embedder,
    # location=":memory:",
    collection_name=COLLECTION_NAME,
    retrieval_mode=RetrievalMode.HYBRID,
    # force_recreate=True
)

# %%
# query = "What did the president say about Ketanji Brown Jackson"
# found_docs = qdrant.similarity_search(query)
# found_docs

# query = "Итоги запусков кампаний по категории бытовой химии"
# query = "Успешные кампании кофе и чай"
query = "Итоги запусков кампаний по категории молочная продукция"
query = 'query: ' + query
found_docs = qdrant.similarity_search(query, k=3)
# for score, text in hybrid_search(query, alpha=0.8, top_k=5):
for f in found_docs:
    # print(f"{score:.3f} — {f.page_content}")
    print(f"{f.page_content}")
    print('-'*80)
# Out:
# passage: Настоящий отчет подготовлен по результатам акция в регионе Урал. Основной целью являлось повышение продаж и вовлеченности по категории Молочная продукция. Несмотря на корректную реализацию кампании, существенного роста ключевых показателей не зафиксировано. Кампания началась с оптимистичных ожиданий, однако уже в первые дни стало ясно, что уровень вовлеченности аудитории ниже прогнозируемого. Основные показатели остались на уровне контрольного периода, что указывает на слабое восприятие механики. Причинами неуспеха стали низкая узнаваемость, ограниченный бюджет на медийное продвижение и недостаточная персонализация предложений. Следует уделить внимание более точному позиционированию кампании и выбору каналов с наибольшим откликом. Несмотря на обширный охват, кампания не вызвала заметного увеличения количества визитов или среднего чека. Вероятно, потребители не восприняли предложение как достаточно ценное. Дополнительный анализ показал, что поведение покупателей оставалось стабильным
# --------------------------------------------------------------------------------
# passage: В рамках серии кампаний проведено 12 A/B-тестов: - тест времени отправки push: +0,5 п.п. CTR при отправке 17:00–18:00 вместо 20:00;.
#  - тест креативов email-рассылок: +0,7 п.п. CTR при персонализации по категории товаров;.
#  - тест заголовков push-сообщений: прирост конверсии +4,8 %;.
#  - тест глубины скидки: оптимальный уровень — −15 % (выше — снижение ROMI);.
#  - тест Telegram-коммуникации: ROMI 106 %, Retention 76 %, вовлечение +1,1 п.п..
#  Вывод: подтверждена гипотеза, что умеренные скидки (до 15 %) и персонализация по истории покупок обеспечивают максимальный баланс ROMI и удержания. [Title] 6. Влияние на ключевые KPI.
#  Показатель До кампаний После кампаний Изменение ROMI (средний) 100 % 106 % +6 п.п. Retention 72 % 76 % +4 п.п. CTR (в среднем) 3,2 % 3,7 % +0,5 п.п. Средний чек 480 ₽ 497 ₽ +3,5 % Доля digital-продаж 36 % 41 % +5 п.п. Рост показателей подтверждает, что сочетание digital и CRM-коммуникаций усиливает общий ROMI.
# --------------------------------------------------------------------------------
# passage: [Title] Отчет по CRM-кампании: Тестовая персонализация — сегмент Семьи с детьми, ПФО, январь 2025.
#  [Title] CRM-акция (сводка).
#  Тип кампании: Тестовая персонализация Регион: ПФО Сегмент: Семьи с детьми Основная цель — увеличение частоты визитов на 10–15%. [Title] Результаты.
#  - Количество участников: 748713.
#  - Средний чек: 734 ₽.
#  - Доля digital-продаж: 40.5%.
#  [Title] Рекомендации.
#  Добавить геймификацию, пересмотреть текст push-сообщений и время отправки.
# --------------------------------------------------------------------------------

# %%
qdrant.similarity_search_with_score(query, k=3)
# Out:
# [(Document(metadata={'doc_id': 7, 'file_path': './data/raw/Акция — Урал — Молочная продукция (февраль 2025).docx', '_id': '544ea6b4-fd90-4518-9a99-7444fae4d48b', '_collection_name': 'hybrid_docs'}, page_content='passage: Настоящий отчет подготовлен по результатам акция в регионе Урал. Основной целью являлось повышение продаж и вовлеченности по категории Молочная продукция. Несмотря на корректную реализацию кампании, существенного роста ключевых показателей не зафиксировано. Кампания началась с оптимистичных ожиданий, однако уже в первые дни стало ясно, что уровень вовлеченности аудитории ниже прогнозируемого. Основные показатели остались на уровне контрольного периода, что указывает на слабое восприятие механики. Причинами неуспеха стали низкая узнаваемость, ограниченный бюджет на медийное продвижение и недостаточная персонализация предложений. Следует уделить внимание более точному позиционированию кампании и выбору каналов с наибольшим откликом. Несмотря на обширный охват, кампания не вызвала заметного увеличения количества визитов или среднего чека. Вероятно, потребители не восприняли предложение как достаточно ценное. Дополнительный анализ показал, что поведение покупателей оставалось стабильным'),
#   1.0),
#  (Document(metadata={'doc_id': 14, 'file_path': './data/raw/Тестовая персонализация — ПФО — Семьи с детьми (январь 2025).docx', '_id': '34fb30b7-af6c-4f8d-87a1-2791515b2388', '_collection_name': 'hybrid_docs'}, page_content='passage: [Title] Отчет по CRM-кампании: Тестовая персонализация — сегмент Семьи с детьми, ПФО, январь 2025.\n [Title] CRM-акция (сводка).\n Тип кампании: Тестовая персонализация Регион: ПФО Сегмент: Семьи с детьми Основная цель — увеличение частоты визитов на 10–15%. [Title] Результаты.\n - Количество участников: 748713.\n - Средний чек: 734 ₽.\n - Доля digital-продаж: 40.5%.\n [Title] Рекомендации.\n Добавить геймификацию, пересмотреть текст push-сообщений и время отправки.'),
#   0.33333334),
#  (Document(metadata={'doc_id': 5, 'file_path': './data/raw/Тестирование механик стимулирования продаж (апрель–июнь 2025).docx', '_id': 'c1386d84-8289-428d-8079-0bfdb0fef2ef', '_collection_name': 'hybrid_docs'}, page_content='passage: В рамках серии кампаний проведено 12 A/B-тестов: - тест времени отправки push: +0,5 п.п. CTR при отправке 17:00–18:00 вместо 20:00;.\n - тест креативов email-рассылок: +0,7 п.п. CTR при персонализации по категории товаров;.\n - тест заголовков push-сообщений: прирост конверсии +4,8 %;.\n - тест глубины скидки: оптимальный уровень — −15 % (выше — снижение ROMI);.\n - тест Telegram-коммуникации: ROMI 106 %, Retention 76 %, вовлечение +1,1 п.п..\n Вывод: подтверждена гипотеза, что умеренные скидки (до 15 %) и персонализация по истории покупок обеспечивают максимальный баланс ROMI и удержания. [Title] 6. Влияние на ключевые KPI.\n Показатель До кампаний После кампаний Изменение ROMI (средний) 100 % 106 % +6 п.п. Retention 72 % 76 % +4 п.п. CTR (в среднем) 3,2 % 3,7 % +0,5 п.п. Средний чек 480 ₽ 497 ₽ +3,5 % Доля digital-продаж 36 % 41 % +5 п.п. Рост показателей подтверждает, что сочетание digital и CRM-коммуникаций усиливает общий ROMI.'),
#   0.33333334)]

# %%
retriever = qdrant.as_retriever(search_kwargs={"k": 3})
docs = retriever.invoke(query)
for doc in docs:
    print(doc.metadata)
# Out:
# {'doc_id': 7, 'file_path': './data/raw/Акция — Урал — Молочная продукция (февраль 2025).docx', '_id': '544ea6b4-fd90-4518-9a99-7444fae4d48b', '_collection_name': 'hybrid_docs'}
# {'doc_id': 5, 'file_path': './data/raw/Тестирование механик стимулирования продаж (апрель–июнь 2025).docx', '_id': 'c1386d84-8289-428d-8079-0bfdb0fef2ef', '_collection_name': 'hybrid_docs'}
# {'doc_id': 14, 'file_path': './data/raw/Тестовая персонализация — ПФО — Семьи с детьми (январь 2025).docx', '_id': '34fb30b7-af6c-4f8d-87a1-2791515b2388', '_collection_name': 'hybrid_docs'}
